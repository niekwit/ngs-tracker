# %% [markdown]
# # PDAC single-cell atlas — UMAP visualisation

# %%
import scanpy as sc
adata = sc.read_h5ad('pdac_atlas.h5ad')
sc.pl.umap(adata, color=['cell_type', 'sample'], save='_celltypes.png')
